# %%
require 'cbioportal'
# Out:
# "if(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min\",\"downloadable\":\"http://cdn.rawgit.com/domitry/d3-downloadable/master/d3-downloadable\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"},\"downloadable\":{\"exports\":\"downloadable\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');require(['downloadable'], function(downloadable){window['downloadable']=downloadable;console.log('finished loading downloadable');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"http://cdn.rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\n\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    w
# ...

# %%
C
# Out:
# #<CBioPortal:0x0000555e1abb8e60>

# %%
C.get_all_studies
# Out:
# #<Daru::DataFrame(239x12)>
#             allSampleC cancerType   citation descriptio     groups importDate       name       pmid publicStud  shortName     status    studyId
#           0         34       blca Al-Ahmadie Genomic pr     PUBLIC        nil Bladder Ca   26901067       true Bladder PV          0 blca_plasm
#           1         40       hnsc Pickering  Comprehens                   nil Oral Squam   23619168       true Head & nec          0 hnsc_mdand
#           2         46       liad Pilati et  Mutation d                   nil Hepatocell   24735922       true Liad (Inse          0 liad_inser
#           3         56        nbl Peifer et  Mutation d                   nil Neuroblast   26466568       true NBL (Colog          0 nbl_ucolog
#           4         10      panet Cao et al. Whole exom                   nil Insulinoma   24326773       true Panet (Sha          0 panet_shan
# ...

# %%
C.get_all_cancer_types
# Out:
# #<Daru::DataFrame(853x6)>
#                   name clinicalTr dedicatedC  shortName     parent cancerType
#           0 Aggressive aggressive LightYello         AA soft_tissu         aa
#           1 Anaplastic anaplastic       Gray      AASTR       difg      aastr
#           2 Activated  activated   LimeGreen        ABC   dlbclnos        abc
#           3 Acute Baso acute baso LightSalmo        ABL     amlnos        abl
#           4 Adrenocort adrenocort     Purple        ACA adrenal_gl        aca
#           5 Adenoid Cy adenoid cy    HotPink       ACBC       brca       acbc
#           6 Adrenocort adrenocort     Purple        ACC adrenal_gl        acc
#           7 Acinic Cel acinic cel    DarkRed       ACCC       saca       accc
#           8 Atypical C atypical c LightSalmo       ACML    mds/mpn       acml
#           9 Acinar Cel acinar cel      Black        ACN        cup        acn
#          10 Craniophar craniophar       Gray       ACPG       selt       acpg
# ...

# %%
C.get_all_genes
# Out:
# #<Daru::DataFrame(100000x6)>
#             chromosome   cytoband entrezGene hugoGeneSy     length       type
#           0         11    11q13.1     -79138 SPINDOC_PS          0 phosphopro
#           1         11    11q13.1     -79137 SPINDOC_PS          0 phosphopro
#           2         16    16p12.3     -79136 VPS35L_PS1          0 phosphopro
#           3          1     1q32.1     -79135 INAVA_PS48          0 phosphopro
#           4          9     9q31.3     -79134 ECPAS_PS18          0 phosphopro
#           5         17    17p13.3     -79133 TRARG1_PS5          0 phosphopro
#           6         10    10p15.1     -79132  FBH1_PS79          0 phosphopro
#           7         19    19p13.3     -79131 YJU2_PT301          0 phosphopro
#           8          9     9q31.3     -79130 ECPAS_PT12          0 phosphopro
#           9         17    17p13.3     -79129 TRARG1_PS6          0 phosphopro
#          10         17    17p13.3     -79128 TRARG1_PS7          0 phosphopro
# ...

# %%
C.get_all_molecular_profiles
# Out:
# #<Daru::DataFrame(886x7)>
#             molecularA   datatype       name descriptio showProfil molecularP    studyId
#           0 COPY_NUMBE   DISCRETE Putative c Putative c       true acbc_mskcc acbc_mskcc
#           1 MUTATION_E        MAF  Mutations Whole exom       true acbc_mskcc acbc_mskcc
#           2 PROTEIN_LE LOG2-VALUE Protein ex Protein ex      false acc_tcga_r   acc_tcga
#           3 PROTEIN_LE    Z-SCORE Protein ex Protein ex       true acc_tcga_r   acc_tcga
#           4 COPY_NUMBE   DISCRETE Putative c Putative c       true acc_tcga_g   acc_tcga
#           5 MRNA_EXPRE CONTINUOUS mRNA expre Expression      false acc_tcga_r   acc_tcga
#           6 MRNA_EXPRE    Z-SCORE mRNA Expre mRNA z-Sco       true acc_tcga_r   acc_tcga
#           7 COPY_NUMBE CONTINUOUS Relative l Relative l      false acc_tcga_l   acc_tcga
#           8 METHYLATIO CONTINUOUS Methylatio Methylatio      false acc_tcga_m   acc_tcga
# ...

# %%
C.get_all_clinical_attributes
# Out:
# #<Daru::DataFrame(9743x7)>
#             displayNam descriptio   datatype patientAtt   priority clinicalAt    studyId
#           0 Adjuvant C Adjuvant C     STRING       true          1 ADJUVANT_C acbc_mskcc
#           1 Adjuvant T Adjuvant t     STRING       true          1 ADJUVANT_T acbc_mskcc
#           2 Diagnosis  Age at whi     NUMBER       true          1        AGE acbc_mskcc
#           3 Cancer Typ Disease ty     STRING      false          1 CANCER_TYP acbc_mskcc
#           4 Cancer Typ Cancer Typ     STRING      false          1 CANCER_TYP acbc_mskcc
#           5 ER Status  breast car     STRING      false          1 ER_STATUS_ acbc_mskcc
#           6 Followup ( Followup i     NUMBER       true          1 FOLLOWUP_Y acbc_mskcc
#           7 Fusion Sta Fusion Sta     STRING      false          1 FUSION_STA acbc_mskcc
#           8 Genomic Al Number of      NUMBER      false          1 GENOMIC_AL acbc_mskcc
# ...

# %%
C.get_all_gene_panels
# Out:
# #<Daru::DataFrame(17x2)>
#             descriptio genePanelI
#           0 Targeted N NSCLC_UNIT
#           1 Targeted (  IMPACT341
#           2 Targeted (  IMPACT410
#           3 Targeted s    bait_v4
#           4 Targeted s    bait_v5
#           5 Targeted s    bait_v3
#           6 Targeted (  IMPACT468
#           7 Targeted s     IMPACT
#           8 Targeted s MSKCC_BLCA
#           9 Targeted (  IMPACT300
#          10 Targeted s   DFCI_504
#          11 Targeted d  UCLA_1202
#          12 Targeted (  IMPACT279
#          13 DNA sequen WUSTL-DFCI
#          14 Targeted m NOVARTIS_B
#         ...        ...        ...

# %%
C.get_all_sample_lists
# Out:
# #<Daru::DataFrame(1359x5)>
#               category       name descriptio sampleList    studyId
#           0 all_cases_ Sequenced  All (Next- acbc_mskcc acbc_mskcc
#           1 all_cases_ Tumor Samp All tumor  acbc_mskcc acbc_mskcc
#           2 all_cases_ Tumor Samp All tumors acbc_mskcc acbc_mskcc
#           3 all_cases_ All Tumors All tumor  acbc_mskcc acbc_mskcc
#           4 all_cases_ Tumor Samp All sample acc_tcga_m   acc_tcga
#           5 all_cases_ All tumor  All sample acc_tcga_m   acc_tcga
#           6 all_cases_ All Sequen All sequen acc_tcga_s   acc_tcga
#           7 all_cases_ Tumor Samp All tumor  acc_tcga_c   acc_tcga
#           8 all_cases_ Tumor Samp All tumors acc_tcga_c   acc_tcga
#           9 all_cases_ Tumor Samp All sample acc_tcga_r   acc_tcga
#          10 all_cases_ All Tumors All tumor  acc_tcga_a   acc_tcga
#          11 all_cases_ All Comple All tumor  acc_tcga_3   acc_tcga
#          12 all_cases_ Tumor Samp Tumors wit acc_tcga_r   acc_tcga
# ...
